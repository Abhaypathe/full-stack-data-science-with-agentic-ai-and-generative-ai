# %% [markdown]
# # CPU
#
# - cpu has 3 part - CU (Contol Unit) | MU(Memory Unit) | ALU (Arithmetic | Logic unit)
#
# ### MEMORY UNIT -->
# so far we work in memory unit-that means we save variable in memory & call the varible from memory & trying to save the data with the help of variable
#
# ### ARITHMETIC UNIT -->
# when it comes to Arithmetic unit it performs calculation & we done so far addition, substraction, multiplication , division.
#
# ### LOGICAL UNIT -->
# when i talk about logical unit which makes your computer to think means user programed so that and let your computer think. in real life also we apply many condition to reach the goal. if this not possible then we can do that for example. e.g after complet +2 which field you can go for
# if not this field else what is other files. while we talk amoung each other many situation unknowily we are using if else condition.

# %% [markdown]
# LETS UNDERSTAND THE CONDITION TO COMPUTER TO THINK FOR THAT WE HAVE SOME SPECIAL KEYWORD

# %% [markdown]
# # conditional statement
# - if
# - if else
# - if elif else
# - nested if

# %%
if True: 
    print('Data Science')
# Out:
# Data Science

# %%
if False:
    print('Data Science')
print('bye for now')
# Out:
# bye for now

# %%
if True:
    print('Data Science')
print('bye for now')
# Out:
# Data Science
# bye for now

# %%
if True:
    print('Data Science')
else:
    print('bye for now')
# Out:
# Data Science

# %%
if False:
    print('Data Science job')
else:
    print('no job')
# Out:
# no job

# %% [markdown]
# Lets do one program as if divide by 2 then reminder is 0 then it is even number
# if reminder is not 0 then it is odd number

# %%
x = 4 
r = x % 2 

if r == 0:
    print('Even number')
# Out:
# Even number

# %%
x = 5
r = x % 2 

if r == 0:
    print('Even number')

# %%
x = 5
r = x % 2 

if r != 0:
    print('Odd number')
# Out:
# Odd number

# %%
x = 7
r = x % 2 

if r == 1:
    print('Odd number')
# Out:
# Odd number

# %%
x = 5
r = x % 2 

if r == 0:
    print('Even number')
    
print('odd number')
# Out:
# odd number

# %%
x = 4
r = x % 2 

if r == 0:
    print('Even number')
    
print('odd number')
# Out:
# Even number
# odd number

# %%
x = 9
r = x % 2 

if r == 0:
    print('Even number')
    
if r == 1:
    print('odd number')
# Out:
# odd number

# %% [markdown]
# # IF ELSE

# %% [markdown]
# if we observe the code its too many line cuz many of the coder always they wanted to reduce the code lenght which is very good practise. instead of 2 if we can use if-- else

# %%
 x= 8
r = x % 2 

if r == 0:
    print('Even number')
    
else:
    print('odd number')
# Out:
# Even number

# %%
x = 9
r = x % 2 

if r !=  0:
    print('odd number')
    
else:
    print('even number')
# Out:
# odd number

# %% [markdown]
# # NESTED IF

# %%
x = 3
r = x % 2

if r == 0:
    print('Even number')
    if x>5:
        print('greater number')

else:
    print('Odd Number')
# Out:
# Odd Number

# %%
x = 4
r = x % 2

if r == 0:
    print('Even number')
    
    if x>5:
        print('greater number')

else:
    print('Odd Number')
# Out:
# Even number

# %%
x = 4
r = x % 2

if r == 0:
    print('Even number')
    
    if x>5:
        print('greater number')
    else:
        print('lesser number')

else:
    print('Odd Number')
# Out:
# Even number
# lesser number

# %%
x = 13
r = x % 2

if r == 0:
    print('Even number')
    
    if x>5:
        print('greater number')
    else:
        print('lesser number')

else:
    print('Odd Number')
# Out:
# Odd Number

# %% [markdown]
# # IF ELIF ELSE

# %%
x = 3

if x == 1:
    print('one')
if x == 2:
    print('Two')
if x == 3:
    print('Three')
if x == 4:
    print('four')
# Out:
# Three

# %%
x = 1

if x == 1:
    print('one')
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('four')
# Out:
# one

# %%
x = 5

if x == 1:
    print('one')
    
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('four')

else:
    print('number not found')
# Out:
# number not found

# %%
age = 19
if age > 18: print("Eligible to Vote.")
# Out:
# Eligible to Vote.

# %%
#short hand if 
a = 30
b = 20
if a > b: print("a is greater than b")
# Out:
# a is greater than b
