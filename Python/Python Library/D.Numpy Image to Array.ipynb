# %%
 import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image  #python image library

# %%
image = Image.open(r"C:\Users\pathe\OneDrive\Pictures\plant.jfif")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x276>

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
image_arr = np.asarray(image)
image_arr
# Out:
# array([[[ 9, 11,  8],
#         [ 9, 11,  8],
#         [ 9, 11,  8],
#         ...,
#         [26, 35, 34],
#         [28, 34, 34],
#         [27, 33, 33]],
#
#        [[ 9, 11,  8],
#         [ 9, 11,  8],
#         [10, 12,  9],
#         ...,
#         [26, 35, 34],
#         [28, 34, 34],
#         [28, 34, 34]],
#
#        [[ 9, 11,  8],
#         [10, 12,  9],
#         [10, 12,  9],
#         ...,
#         [27, 36, 35],
#         [28, 34, 34],
#         [28, 34, 34]],
#
#        ...,
#
#        [[41, 54, 37],
#         [29, 43, 26],
#         [34, 47, 30],
#         ...,
#         [54, 56, 43],
#         [46, 48, 35],
#         [39, 41, 28]],
#
#        [[32, 45, 28],
#         [26, 40, 23],
#         [40, 53, 36],
#         ...,
#         [56, 58, 45],
#         [42, 44, 31],
#         [36, 38, 25]],
#
#        [[28, 41, 24],
#         [27, 41, 24],
#         [38, 51, 34],
#         ...,
#         [58, 60, 47],
#         [39, 41, 28],
#         [34, 36, 23]]], dtype=uint8)

# %%
image_arr.shape
# Out:
# (276, 183, 3)
