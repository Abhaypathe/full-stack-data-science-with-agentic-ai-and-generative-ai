# %% [markdown]
# # TUPLES
# ---------------------------------------------------------------------
# 1. Tuples is similar to list except tuple are immutable which means we can't change the elemnts of a tuple once assigned
#
# 2. when we don't want to chnage the data over time, tuple is preffred data type
#
# 3.iterating over the elements of a tuple is faster compared to iterating over a list.

# %%
recap:
- empty tuple()

- Each item seperated by(,,,,)

-it is heterogenous 

-within the tuple ,tuple is added->nested

-indexing

-slicing

-no replace(immutable)

# %% [markdown]
# # empty Tuple

# %%
t=()
print(t)
type(t)
# Out:
# ()
# tuple

# %%
l=[]
print(l)
type(l)
# Out:
# []
# list

# %%
t=(1,2.5,True,"abc",[2,2])
t
# Out:
# (1, 2.5, True, 'abc', [2, 2])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 5

# %% [markdown]
# # Nested Tuple

# %%
tup=('abhay',23,34.5,True,[45,65],[34,54,65])
tup
# Out:
# ('abhay', 23, 34.5, True, [45, 65], [34, 54, 65])

# %%
len(tup)
# Out:
# 6

# %% [markdown]
# # Tuple indexing

# %%
tup=('abc',25,25.4,True,[60,[10,200]])
tup
# Out:
# ('abc', 25, 25.4, True, [60, [10, 200]])

# %%
len(tup)
# Out:
# 5

# %%
tup[-1]
# Out:
# [60, [10, 200]]

# %%
tup[-1][0]
# Out:
# 60

# %%
tup[-1][1]
# Out:
# [10, 200]

# %%
tup[-1][1][0]
# Out:
# 10

# %%
l1=[10,20,[30,40,[50,60,"hello"]],80]
l1
# Out:
# [10, 20, [30, 40, [50, 60, 'hello']], 80]

# %%
l1[2]
# Out:
# [30, 40, [50, 60, 'hello']]

# %%
l1[2][2]
# Out:
# [50, 60, 'hello']

# %%
l1[2][2][1]
# Out:
# 60

# %%
l1[2][2][2]
# Out:
# 'hello'

# %%
l1[2][2][2][1]
# Out:
# 'e'

# %% [markdown]
# # Tuple Slicing

# %%
t=(1,2,3,4,5)
t[:3]
# Out:
# (1, 2, 3)

# %%
t[:5]
# Out:
# (1, 2, 3, 4, 5)

# %%
t1=[1,[4,5,6],(9,10,25),5,(55,60)]
t1
# Out:
# [1, [4, 5, 6], (9, 10, 25), 5, (55, 60)]

# %%
t1[2]
# Out:
# (9, 10, 25)

# %%
t1[:2]
# Out:
# [1, [4, 5, 6]]

# %%
t1[2][:2]
# Out:
# (9, 10)

# %% [markdown]
# # Tuple concatenation

# %%
t1=(1,2,3)
t2=(4,5,6,7)
t1+t2
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %% [markdown]
# # replace

# %%
t=[1,2,3,4]
print(type(t))
t[1]=20
print(t)
# Out:
# <class 'list'>
# [1, 20, 3, 4]

# %%
t=(1,2,3,4)
print(type(t))
#t[1]=20
print(t)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4)

# %%
t=(1,2,3,4)
print(type(t))
t[1]=20
print(t)            #no modification
# Out:
# <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 t=(1,2,3,4)
#       2 print(type(t))
# ----> 3 t[1]=20
#       4 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # INTERVIEW

# %% [markdown]
# MUTABLE VS IMMUTABLE
# MUTABLE
# Eg: list
# modify value in original object
#
# IMMUTABLE
# Eg:tuple
# no modifiaction

# %% [markdown]
# # Interview question..................
#
# t=(1,2,3,4,5,[6,7,8])
# can we modify 6 with 60?
# -->yes..

# %%
t=(1,2,3,4,5,[6,7,8])
a=t[-1]
a[0]=60
t[-1][0]
print(t)
print(id)
# Out:
# (1, 2, 3, 4, 5, [60, 7, 8])
# <built-in function id>

# %%
t=(1,2,3,4,5,[6,7,8])
t[-1].append(9)
t
# Out:
# (1, 2, 3, 4, 5, [6, 7, 8, 9])

# %% [markdown]
# ******************Tuple Methods**********************

# %%
mytuple1=(1,1,2,3,4,5,[1,2,3,4,1,1])
mytuple1
# Out:
# (1, 1, 2, 3, 4, 5, [1, 2, 3, 4, 1, 1])

# %% [markdown]
# # tuple.count()
# -Numbers of items occured in the tuple

# %%
mytuple1.count(1)
# Out:
# 2

# %% [markdown]
# # tuple.index()
# positive index number of first occurence of item

# %%
mytuple1.index(1)
# Out:
# 0

# %%
mytuple1.index(3)
# Out:
# 3

# %%
mytuple1.index(6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 mytuple1.index(6)
#
# ValueError: tuple.index(x): x not in tuple

# %%
mytuple1.index(5)
# Out:
# 5

# %% [markdown]
# # Delete entire tuple

# %%
mytuple=(1,2,3)
del mytuple
